# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("../data/trainingDataPAM4_CD_PD.csv")

plt.figure(figsize=(8,4))
plt.plot(df["rx_real"][:2000])
plt.title("First 2000 received samples")
plt.show()
